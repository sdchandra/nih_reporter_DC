# %% [markdown]
# # Exploring raw data downloaded from NIH Reporter

# %%
import pandas as pd

# Location to one year's abstracts csv file
infile = "/Users/chandranandadineika/Downloads/RePORTER_PRJABS_C_FY1985.csv"

abs_per_year = pd.read_csv(infile)

# Filter only useful columns and drop duplicated reviews
abs_per_year = abs_per_year[["APPLICATION_ID", "ABSTRACT_TEXT"]]
abs_per_year = abs_per_year.drop_duplicates()

# Remove missing values
abs_per_year = abs_per_year.dropna()

abs_per_year
# Out:
#        APPLICATION_ID                                      ABSTRACT_TEXT
# 0             3126545  The aim of this proposal is an understanding o...
# 1             3126549  The alternative pathway of complement activati...
# 2             3126553  We will study virus-host cell interactions wit...
# 3             3109190  Chronic ingestion of enthanol impairs the cont...
# 4             3109194  The effects of ethanol exposure on central ner...
# ...               ...                                                ...
# 41335         3109093  Mitochondrial aldehyde dehydrogenase is isolat...
# 41336         3109098  In utero growth retardation resulting from mat...
# 41337         3109100  Clinical studies and those in experimental ani...
# 41338         3109109  The long range goal of our research is to dete...
# 41339         3153184  Abstract: The proposed field trial, motivated ...
#
# [25907 rows x 2 columns]
